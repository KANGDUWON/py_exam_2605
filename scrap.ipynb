# %%
# 웹 페이지를 요청하고 응답 데이터를 받을 수 있다.
import requests as req
from bs4 import BeautifulSoup # BeautifulSoup html 해석기

# %%
# 요청시 오류 났을 때 아래 문구를 입력해주세요.
request_headers = {'User-Agent': ('Mozilla/5.0 (Windows NT 10.0;Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98Safari/537.36'), }

# %%
# 특정 사이트에 페이지를 요청. 응답 데이터 반환
res = req.get('https://www.naver.com/', request_headers)
# print(res)

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""
# print(html_doc)
# soup을 이용해서 html_doc 문자열 파싱. 그 내용을 soup 변수에 대입
soup = BeautifulSoup(html_doc, 'html.parser')

alist = soup.select('a')
print(alist)
print(alist[0])
print(alist[0].text)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# Elsie

# %%
import requests as req
from bs4 import BeautifulSoup

res = req.get('https://news.naver.com/')

#print(res.text)
soup = BeautifulSoup(res.text,'html.parser')
content = soup.select('')
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# Cell In[23], line 8
#       4 res = req.get('https://news.naver.com/')
#       5
#       6 #print(res.text)
#       7 soup = BeautifulSoup(res.text,'html.parser')
# ----> 8 content = soup.select('')
#
# File c:\Users\201\AppData\Local\Programs\Python\Python314\Lib\site-packages\bs4\element.py:3149, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    3126 def select(
#    3127     self,
#    3128     selector: str,
#    (...)   3131     **kwargs: Any,
#    3132 ) -> ResultSet[Tag]:
#    3133     """Perform a CSS selection operation on the current element.
#    3134
#    3135     This uses the SoupSieve library.
#    (...)   3147        soupsieve.select() method.
#    3148     """
# -> 3149     return self.css.select(selector, namespaces, limit, **kwargs)
#
# ...

# %%
# print(alist[0]['href'])

# for a in alist:
#     print(a.text)

# for link in alist:
#     print(link['href'])
# Out:
# http://example.com/elsie
# Elsie
# Lacie
# Tillie
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie
